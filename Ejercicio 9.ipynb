# %%
# !pip install pycryptodome

import hashlib
from base64 import b64encode, b64decode
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad, unpad

# Texto plano de 16 bytes de ceros binarios
textoPlano_bytes = bytes.fromhex('00000000000000000000000000000000')

# Clave (en formato hexadecimal) que se utilizará para calcular el KCV
clave = bytes.fromhex('A2CFF885901A5449E9C448BA5B948A8C4EE377152B3F1ACFA0148FB3A426DB72')

# Vector de inicialización (IV) de 16 bytes
iv_bytes = bytes.fromhex('00000000000000000000000000000000')

# Cifrado AES en modo CBC
cipher = AES.new(clave, AES.MODE_CBC, iv_bytes)

# Cifrar el texto plano con relleno PKCS7
texto_cifrado_bytes = cipher.encrypt(pad(textoPlano_bytes, AES.block_size, style='pkcs7'))

# Imprimir el KCV (primeros 6 bytes del texto cifrado en hexadecimal)
print("KCV AES:", texto_cifrado_bytes.hex()[0:6])

# Calcular el KCV con SHA-256 de la clave (sin cifrar)
m = hashlib.sha256()
m.update(clave)
print("KCV SHA256:", m.digest().hex()[0:6])
# Out:
# Collecting pycryptodome
#   Downloading pycryptodome-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Downloading pycryptodome-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 22.2 MB/s eta 0:00:00
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.21.0
# KCV AES: 5244db
# KCV SHA256: db7df2
